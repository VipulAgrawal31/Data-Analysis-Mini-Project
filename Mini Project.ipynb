# %%
pwd
# Out:
# 'C:\\Users\\DELL\\DAY 6'

# %%
import pandas as pd
df = pd.read_csv('Match.csv')

# %%
 # task 1
df['Season_Year'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2017    60
# 2016    60
# 2014    60
# 2010    60
# 2015    59
# 2008    58
# 2009    57
# Name: Season_Year, dtype: int64

# %%
 # task 2 
import pandas as pd
def func(df):
    li = []
    count=0
    columns = df['Season_Year']
    for i in columns:
        if (i==2011):
            li.append(df.values[count])
        count+=1
    return li
a=pd.DataFrame(pdfc(df),columns=df.columns)
a
# Out:
#     Match_SK  match_id                        Team1  \
# 0        175    501203          Chennai Super Kings
# 1        176    501204              Deccan Chargers
# 2        177    501205         Kochi Tuskers Kerala
# 3        178    501206             Delhi Daredevils
# 4        179    501207                Pune Warriors
# 5        180    501208        Kolkata Knight Riders
# 6        181    501209             Rajasthan Royals
# 7        182    501210  Royal Challengers Bangalore
# 8        183    501211              Kings XI Punjab
# 9        184    501212                Pune Warriors
# 10       185    501213              Deccan Chargers
# 11       186    501214             Rajasthan Royals
# 12       187    501215               Mumbai Indians
# 13       188    501216          Chennai Super Kings
# 14       189    501217              Deccan Chargers
# 15       190    501218                Pune Warriors
# 16       191    501219        Kolkata Knight Riders
# ...

# %%
t= list(a['match_winner'].unique())
li_st={}
for i in t:
    li_st[i]=0
for i in a['match_winner']:
    li_st[i]+=1
del li_st[np.nan]

# %%
import numpy as np
import matplotlib.pyplot as plt
index=np.arange(0,len(li_st))
plt.barh(index,li_st.values(),color="green")
plt.yticks(index,graph)
plt.show()

# %%
# task 3
graph =pd.DataFrame(df[df['City_Name']=='Hyderabad'])

z=graph['ManOfMach'].unique()
y=pd.DataFrame(graph['ManOfMach'].value_counts())
y
# Out:
#                    ManOfMach
# DA Warner                  6
# DW Steyn                   3
# GH Vihari                  2
# YK Pathan                  2
# V Sehwag                   2
# A Mishra                   2
# SK Raina                   2
# I Sharma                   1
# B Kumar                    1
# MR Marsh                   1
# SK Trivedi                 1
# PC Valthaty                1
# CH Morris                  1
# V Kohli                    1
# MJ McClenaghan             1
# Mandeep Singh              1
# PA Patel                   1
# SE Marsh                   1
# AB Dinda                   1
# DJ Bravo                   1
# SC Ganguly                 1
# SL Malinga                 1
# AT Rayudu                  1
# G Gambhir                  1
# DJG Sammy                  1
# UT Yadav                   1
# R Vinay Kumar              1
# WP Saha                    1
# Mustafizur Rahman          1
